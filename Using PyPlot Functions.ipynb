# %%
import numpy as np
import matplotlib.pyplot as plt
a  = [0, 1, 2, 3, 4, 5]
b = [0, 1, 4, 9, 16, 25]
plt.bar(a,b)
plt.grid('both')
plt.title('graph')
plt.xlabel('X_Value')
plt.ylabel('Y_Value')
plt.show()
